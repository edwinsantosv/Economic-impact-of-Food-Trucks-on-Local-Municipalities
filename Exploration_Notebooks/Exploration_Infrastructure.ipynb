# %%
import pandas as pd
import os
import sweetviz as sv
import geopandas as gpd
from shapely import wkt
import contextily as ctx
import matplotlib.pyplot as plt
import geodatasets

# %%
os.chdir('C:/Users/edwin/OneDrive/Escritorio/Personal files/Courses/Semester 2/Capstone Project/Databases/DB2 - The Open Database of Infrastructure/INF_DB')

# %%
directory_contents = os.listdir('.')
directory_contents
# Out:
# ['bridges_and_tunnels.csv',
#  'pedestrian_and_cycling_1.csv',
#  'pedestrian_and_cycling_2.csv',
#  'pedestrian_and_cycling_3.csv',
#  'pedestrian_and_cycling_4.csv',
#  'potable_water.csv',
#  'public_transit_stops_gtfs.csv',
#  'solid_waste.csv',
#  'wastewater_stormwater_1.csv',
#  'wastewater_stormwater_2.csv',
#  'wastewater_stormwater_3.csv',
#  'wastewater_stormwater_4.csv']

# %%
bridge_tunnels=pd.read_csv('bridges_and_tunnels.csv')
bridge_tunnels.head()
# Out:
#                               INDEX  INFRASTRUCTURE_TYPE INFR_SUB_TYPE  \
# 0  440e343bbf8109c8d233571150ec3835  BRIDGES AND TUNNELS   Footbridges
# 1  82f8352416b6d148b441b0427777dcaa  BRIDGES AND TUNNELS   Footbridges
# 2  6487225458116dbbb6af7112e5e9d484  BRIDGES AND TUNNELS   Footbridges
# 3  37ac1974d1778359dbb90b19a22e02e8  BRIDGES AND TUNNELS   Footbridges
# 4  5b92f9ba2f837ae0531169414d825e7e  BRIDGES AND TUNNELS   Footbridges
#
#                      NAME SOURCE_ID STATUS SOURCE_STATUS  \
# 0                      ..        ..     ..            ..
# 1             Bridge Road        ..     ..            ..
# 2  Trans Labrador Highway        ..     ..            ..
# 3                      ..        ..     ..            ..
# 4                      ..        ..     ..            ..
#
#                    PROVIDER LENGTH WIDTH INSTALLATION_DATE REGION_NAME  \
# 0  Natural Resources Canada     ..    ..                ..      Canada
# ...

# %%
bridge_tunnels.columns
# Out:
# Index(['INDEX', 'INFRASTRUCTURE_TYPE', 'INFR_SUB_TYPE', 'NAME', 'SOURCE_ID',
#        'STATUS', 'SOURCE_STATUS', 'PROVIDER', 'LENGTH', 'WIDTH',
#        'INSTALLATION_DATE', 'REGION_NAME', 'CSDNAME', 'CSDUID', 'PROV_TERR',
#        'PRUID', 'LONGITUDE', 'LATITUDE', 'geometry', 'FEAT_LENGTH'],
#       dtype='object')

# %%
bridge_tunnels.describe()
# Out:
#              CSDUID         PRUID     LONGITUDE      LATITUDE
# count  5.891800e+04  58918.000000  58918.000000  58918.000000
# mean   3.279286e+06     32.504922    -85.346105     47.708528
# std    1.335946e+06     13.410406     20.018048      3.703804
# min    1.001101e+06     10.000000   -140.866030     41.783430
# 25%    2.435020e+06     24.000000   -111.352073     45.198645
# 50%    3.518001e+06     35.000000    -78.866540     46.344375
# 75%    4.802031e+06     48.000000    -71.382657     49.882742
# max    6.208098e+06     62.000000    -52.679740     76.418110

# %%
sv_report = sv.analyze(bridge_tunnels) 
sv_report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...
